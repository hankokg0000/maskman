# %%
import os
import cv2
import numpy as np

# %%
def read_data(csv_path):
    with open(csv_path, "r") as file:
        lines = file.read().splitlines()
    return [ line.split(",") for line in lines ]

# %%
train_data = read_data("train.csv")
test_data = read_data("test.csv")

# %%
def read_and_resize(path, size):
    bgr = cv2.imread(path, cv2.IMREAD_COLOR)
    rgb = cv2.cvtColor(bgr, cv2.COLOR_BGR2RGB)
    return cv2.resize(rgb, size)

# %%
def load_data(data):
    image_list = []
    label_list = []
    for path, name in data:
        image = read_and_resize(path, (32, 32))
        name = int(name)
        image_list.append(image)
        label_list.append(name)
    return np.stack(image_list, axis=0), np.array(label_list)

# %%
x_train, y_train = load_data(train_data)
x_test, y_test = load_data(test_data)

# %%
def label2onehot(label):
    return np.eye(2)[label]

# %%
y_train_onehot = label2onehot(y_train)
y_test_onehot = label2onehot(y_test)

# %%
 x_train = x_train /255
x_test = x_test /255

# %%
 print(x_train.shape,y_train.shape)
print(x_test.shape,y_test.shape)
# Out:
# (3160, 32, 32, 3) (3160,)
# (789, 32, 32, 3) (789,)

# %% [markdown]
# ## Model

# %%
from tensorflow import keras

# %%
model = keras.models.Sequential()

model.add(keras.layers.Conv2D(32, (3, 3), padding="same", input_shape=(32, 32, 3)))
model.add(keras.layers.Activation(keras.activations.relu))

model.add(keras.layers.Conv2D(32, (3, 3), padding="same", input_shape=(32, 32, 3)))
model.add(keras.layers.Activation(keras.activations.relu))

model.add(keras.layers.MaxPool2D(2))

model.add(keras.layers.Conv2D(32, (3, 3), padding="same", input_shape=(32, 32, 3)))
model.add(keras.layers.Activation(keras.activations.relu))

model.add(keras.layers.Conv2D(32, (3, 3), padding="same", input_shape=(32, 32, 3)))
model.add(keras.layers.Activation(keras.activations.relu))

model.add(keras.layers.MaxPool2D(2))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(256))
model.add(keras.layers.Activation(keras.activations.linear))
model.add(keras.layers.Dense(64))
model.add(keras.layers.Activation(keras.activations.linear))
model.add(keras.layers.Dense(2))
model.add(keras.layers.Activation(keras.activations.softmax))

loss_func = keras.losses.categorical_crossentropy
metrics = [
    keras.metrics.categorical_accuracy
]
optimizer = keras.optimizers.Adam(lr=0.0001)

model.compile(loss=loss_func, optimizer=optimizer, metrics=metrics)

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_21 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# activation_22 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 16, 16, 32)        9248
# _________________________________________________________________
# activation_23 (Activation)   (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 16, 16, 32)        9248
# _________________________________________________________________
# activation_24 (Activation)   (None, 16, 16, 32)        0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               524544
# _________________________________________________________________
# activation_25 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                16448
# _________________________________________________________________
# activation_26 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 130
# _________________________________________________________________
# activation_27 (Activation)   (None, 2)                 0
# =================================================================
# Total params: 569,762
# Trainable params: 569,762
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train

# %%
callbacks = [
    keras.callbacks.ReduceLROnPlateau(),
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", 
        monitor='val_loss', 
        mode='min',
        save_best_only=True
    ),
]

# %%
his = model.fit(
    x_train,
    y_train_onehot,
    validation_data=(x_test, y_test_onehot),
    epochs=30,
    batch_size=32,
    verbose=1,
    callbacks=callbacks
)
# Out:
# Train on 3160 samples, validate on 789 samples
# Epoch 1/30
# 3160/3160 [==============================] - 7s 2ms/sample - loss: 0.2767 - categorical_accuracy: 0.8699 - val_loss: 0.1429 - val_categorical_accuracy: 0.9544
# Epoch 2/30
# 3160/3160 [==============================] - 6s 2ms/sample - loss: 0.1189 - categorical_accuracy: 0.9563 - val_loss: 0.1063 - val_categorical_accuracy: 0.9708
# Epoch 3/30
# 3160/3160 [==============================] - 6s 2ms/sample - loss: 0.0952 - categorical_accuracy: 0.9671 - val_loss: 0.0991 - val_categorical_accuracy: 0.9696
# Epoch 4/30
# 3160/3160 [==============================] - 6s 2ms/sample - loss: 0.0901 - categorical_accuracy: 0.9680 - val_loss: 0.0953 - val_categorical_accuracy: 0.9734
# Epoch 5/30
# 3160/3160 [==============================] - 6s 2ms/sample - loss: 0.0820 - categorical_accuracy: 0.9728 - val_loss: 0.0965 - val_categorical_accuracy: 0.9785
# Epoch 6/30
# 3160/3160 [==============================] - 6s 2ms/sample - loss: 0.0770 - categorical_accuracy: 0.9734 - val_loss: 0.0922 - val_categorical_accuracy: 0.9734
# Epoch 7/30
# 3160/3160 [==============================] - 6s 2ms/sample - loss: 0.0753 - categorical_accuracy: 0.9715 - val_loss: 0.0897 - val_categorical_accuracy: 0.9708
# Epoch 8/30
# 3160/3160 [==============================] - 6s 2ms/sample - loss: 0.0716 - categorical_accuracy: 0.9763 - val_loss: 0.0979 - val_categorical_accuracy: 0.9747
# Epoch 9/30
# 3160/3160 [==============================] - 6s 2ms/sample - loss: 0.0694 - categorical_accuracy: 0.9744 - val_loss: 0.0951 - val_categorical_accuracy: 0.9747
# Epoch 10/30
# 3160/3160 [==============================] - 6s 2ms/sample - loss: 0.0655 - categorical_accuracy: 0.9763 - val_loss: 0.0929 - val_categorical_accuracy: 0.9772
# Epoch 11/30
# 3160/3160 [==============================] - 6s 2ms/sample - loss: 0.0626 - categorical_accuracy: 0.9769 - val_loss: 0.0889 - val_categorical_accuracy: 0.9721
# Epoch 12/30
# 3160/3160 [==============================] - 6s 2ms/sample - loss: 0.0619 - categorical_accuracy: 0.9769 - val_loss: 0.0985 - val_categorical_accuracy: 0.9747
# Epoch 13/30
# 3160/3160 [==============================] - 6s 2ms/sample - loss: 0.0587 - categorical_accuracy: 0.9797 - val_loss: 0.1077 - val_categorical_accuracy: 0.9734
# Epoch 14/30
# 3160/3160 [==============================] - 6s 2ms/sample - loss: 0.0568 - categorical_accuracy: 0.9794 - val_loss: 0.1005 - val_categorical_accuracy: 0.9734
# Epoch 15/30
# 3160/3160 [==============================] - 6s 2ms/sample - loss: 0.0496 - categorical_accuracy: 0.9810 - val_loss: 0.0922 - val_categorical_accuracy: 0.9696
# Epoch 16/30
# 3160/3160 [==============================] - 6s 2ms/sample - loss: 0.0514 - categorical_accuracy: 0.9816 - val_loss: 0.0810 - val_categorical_accuracy: 0.9734
# Epoch 17/30
# 3160/3160 [==============================] - 6s 2ms/sample - loss: 0.0415 - categorical_accuracy: 0.9870 - val_loss: 0.0871 - val_categorical_accuracy: 0.9772
# Epoch 18/30
# 3160/3160 [==============================] - 6s 2ms/sample - loss: 0.0434 - categorical_accuracy: 0.9835 - val_loss: 0.0945 - val_categorical_accuracy: 0.9708
# Epoch 19/30
# 3160/3160 [==============================] - 6s 2ms/sample - loss: 0.0416 - categorical_accuracy: 0.9854 - val_loss: 0.0987 - val_categorical_accuracy: 0.9721
# Epoch 20/30
# 3160/3160 [==============================] - 6s 2ms/sample - loss: 0.0376 - categorical_accuracy: 0.9886 - val_loss: 0.0925 - val_categorical_accuracy: 0.9810
# Epoch 21/30
# 3160/3160 [==============================] - 6s 2ms/sample - loss: 0.0353 - categorical_accuracy: 0.9880 - val_loss: 0.1046 - val_categorical_accuracy: 0.9772
# Epoch 22/30
# 3160/3160 [==============================] - 6s 2ms/sample - loss: 0.0342 - categorical_accuracy: 0.9867 - val_loss: 0.1063 - val_categorical_accuracy: 0.9721
# Epoch 23/30
# 3160/3160 [==============================] - 6s 2ms/sample - loss: 0.0328 - categorical_accuracy: 0.9880 - val_loss: 0.1013 - val_categorical_accuracy: 0.9721
# Epoch 24/30
# 3160/3160 [==============================] - 6s 2ms/sample - loss: 0.0267 - categorical_accuracy: 0.9918 - val_loss: 0.1114 - val_categorical_accuracy: 0.9708
# Epoch 25/30
# 3160/3160 [==============================] - 6s 2ms/sample - loss: 0.0277 - categorical_accuracy: 0.9902 - val_loss: 0.1212 - val_categorical_accuracy: 0.9708
# Epoch 26/30
# 3160/3160 [==============================] - 6s 2ms/sample - loss: 0.0225 - categorical_accuracy: 0.9908 - val_loss: 0.1084 - val_categorical_accuracy: 0.9810
# Epoch 27/30
# 3160/3160 [==============================] - 6s 2ms/sample - loss: 0.0154 - categorical_accuracy: 0.9940 - val_loss: 0.1100 - val_categorical_accuracy: 0.9797
# Epoch 28/30
# 3160/3160 [==============================] - 6s 2ms/sample - loss: 0.0142 - categorical_accuracy: 0.9943 - val_loss: 0.1103 - val_categorical_accuracy: 0.9785
# Epoch 29/30
# 3160/3160 [==============================] - 6s 2ms/sample - loss: 0.0139 - categorical_accuracy: 0.9953 - val_loss: 0.1122 - val_categorical_accuracy: 0.9785
# Epoch 30/30
# 3160/3160 [==============================] - 6s 2ms/sample - loss: 0.0134 - categorical_accuracy: 0.9959 - val_loss: 0.1092 - val_categorical_accuracy: 0.9785

# %%
val_loss, val_acc = model.evaluate(x_test,y_test_onehot)
# Out:
# 789/1 [========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
